# %%
using Images

# %%
function image_to_matrix(filename)
    img = Images.load(filename)
    matrix = reverse(Float64.(Gray.(img)), dims=1)
    return matrix
end
# Out:
# image_to_matrix (generic function with 1 method)

# %%
function matrix_to_image(matrix)
    img = reverse(Images.colorview(Gray, matrix), dims=1)
    return img
end
# Out:
# matrix_to_image (generic function with 1 method)

# %%
M = image_to_matrix("image.tif")
# Out:
# 627×1881 Matrix{Float64}:
#  0.14902    0.188235   0.211765  0.192157  …  0.227451   0.14902    0.188235
#  0.152941   0.180392   0.2       0.211765     0.235294   0.192157   0.156863
#  0.176471   0.180392   0.188235  0.196078     0.203922   0.176471   0.145098
#  0.180392   0.196078   0.184314  0.184314     0.168627   0.12549    0.137255
#  0.184314   0.196078   0.211765  0.207843     0.188235   0.137255   0.133333
#  0.168627   0.188235   0.211765  0.247059  …  0.203922   0.129412   0.14902
#  0.156863   0.172549   0.203922  0.235294     0.176471   0.192157   0.192157
#  0.137255   0.141176   0.160784  0.180392     0.113725   0.164706   0.113725
#  0.113725   0.117647   0.121569  0.12549      0.0980392  0.137255   0.184314
#  0.101961   0.0980392  0.109804  0.117647     0.14902    0.14902    0.117647
#  0.0980392  0.0980392  0.121569  0.14902   …  0.137255   0.156863   0.152941
#  0.0901961  0.101961   0.133333  0.184314     0.137255   0.156863   0.133333
#  0.105882   0.105882   0.129412  0.168627     0.160784   0.184314   0.121569
#  ⋮                                         ⋱                        ⋮
#  0.278431   0.278431   0.282353  0.286275  …  0.133333   0.129412   0.0980392
#  0.258824   0.247059   0.243137  0.262745     0.12549    0.109804   0.0941176
#  0.282353   0.254902   0.243137  0.266667     0.137255   0.0980392  0.0745098
#  0.290196   0.282353   0.278431  0.290196     0.109804   0.0862745  0.054902
#  0.313725   0.309804   0.313725  0.321569     0.121569   0.129412   0.0745098
#  0.329412   0.329412   0.321569  0.313725  …  0.137255   0.101961   0.0588235
#  0.321569   0.329412   0.301961  0.270588     0.156863   0.105882   0.0588235
#  0.305882   0.321569   0.298039  0.254902     0.14902    0.12549    0.101961
#  0.301961   0.317647   0.305882  0.282353     0.105882   0.141176   0.14902
#  0.278431   0.301961   0.313725  0.313725     0.0980392  0.141176   0.0823529
#  0.27451    0.286275   0.309804  0.321569  …  0.101961   0.0941176  0.105882
#  0.301961   0.290196   0.301961  0.321569     0.109804   0.0745098  0.117647

# %%
matrix_to_image(M)
# Out:
# 627×1881 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.301961)   …  Gray{Float64}(0.117647)
#  Gray{Float64}(0.27451)       Gray{Float64}(0.105882)
#  Gray{Float64}(0.278431)      Gray{Float64}(0.0823529)
#  Gray{Float64}(0.301961)      Gray{Float64}(0.14902)
#  Gray{Float64}(0.305882)      Gray{Float64}(0.101961)
#  Gray{Float64}(0.321569)   …  Gray{Float64}(0.0588235)
#  Gray{Float64}(0.329412)      Gray{Float64}(0.0588235)
#  Gray{Float64}(0.313725)      Gray{Float64}(0.0745098)
#  Gray{Float64}(0.290196)      Gray{Float64}(0.054902)
#  Gray{Float64}(0.282353)      Gray{Float64}(0.0745098)
#  Gray{Float64}(0.258824)   …  Gray{Float64}(0.0941176)
#  Gray{Float64}(0.278431)      Gray{Float64}(0.0980392)
#  Gray{Float64}(0.298039)      Gray{Float64}(0.0862745)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.0901961)  …  Gray{Float64}(0.133333)
#  Gray{Float64}(0.0980392)     Gray{Float64}(0.152941)
#  Gray{Float64}(0.101961)      Gray{Float64}(0.117647)
#  Gray{Float64}(0.113725)      Gray{Float64}(0.184314)
#  Gray{Float64}(0.137255)      Gray{Float64}(0.113725)
#  Gray{Float64}(0.156863)   …  Gray{Float64}(0.192157)
#  Gray{Float64}(0.168627)      Gray{Float64}(0.14902)
#  Gray{Float64}(0.184314)      Gray{Float64}(0.133333)
#  Gray{Float64}(0.180392)      Gray{Float64}(0.137255)
#  Gray{Float64}(0.176471)      Gray{Float64}(0.145098)
#  Gray{Float64}(0.152941)   …  Gray{Float64}(0.156863)
#  Gray{Float64}(0.14902)       Gray{Float64}(0.188235)
